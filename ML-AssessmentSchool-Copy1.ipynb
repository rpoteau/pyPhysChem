# %%
import os
import sys

cwd0 = './config/'
sys.path.append(cwd0)

import visualID_Eng as vID
vID.init(cwd0)
import tools4pyPhysChem as t4pPC

#cancel the "last show-up" behaviour of Jupyter notebooks
# from IPython.core.interactiveshell import InteractiveShell
# InteractiveShell.ast_node_interactivity = "all"
# Out:
# <style>
# h1, h2, h3, h4, h5, h6 {
#   font-family: Verdana, "DejaVu Sans", "Bitstream Vera Sans", Geneva, sans-serif;
#   font-weight: bold;
# }
# body, intro, introE, introT, rq, rqE, rqT, ex, exE, app, appE, sol, todo, hint, hintE, figure  {
#   font-family: Verdana, "DejaVu Sans", "Bitstream Vera Sans", Geneva, sans-serif;
#   font-weight: 400;
#   font-size: 12px;
# }
# h1 {
#   border: 0 solid #333;
#   padding: 30px ;
#   color: white;
#   background: #b11d01;
#   text-align: center;
# }
# h2 {
#   border: 3px solid #333;
#   padding: 18px ;
#   color: #b11d01;
#   background: #ffffff;
#   text-align: center;
# }
# h3 {
#   border: 0 solid #333;
#   padding: 12px ;
#   color: #000000;
#   background: #c1c1c1;
#   text-align: left;
# }
# h4 {
#   border: 0 solid #333;
#   padding: 2px ;
#   color: #000000;
#   background: #d9fffc;
#   text-align: left;
# }
# h5 {
#   border: 1px solid #333;
#   padding: 2px ;
#   color: #000000;
#   background: #ffffff;
#   text-align: left;
# }
# .introT::before {
#     content: attr(title);
#     background-color: #cecece;
#     margin-left:-0.5em;
#     margin-right:-0.5em;
#     padding-left:0.5em;
#     padding-right:0.5em;
#     font-weight: 600;
#     display: block;
# }
# .introT {
#     background-color: #cecece80;
#     border-color: #969696;
#     border-left: 5px solid #969696;
#     padding: 0.5em;
# }
# .intro {
#     background-color: #cecece80;
#     border-color: #969696;
#     border-left: 5px solid #969696;
#     padding: 0.5em;
# }
# .introE {
#     background-color: #cecece80;
#     border-color: #969696;
#     border-left: 5px solid #969696;
#     padding: 0.5em;
#     color : #117996;
# }
# .rq::before {
#     background-color: #fcd3d3;
#     color: #ff0000;
#     content:"Remarque";
#     margin-left:-0.5em;
#     margin-right:-0.5em;
#     padding-left:0.5em;
#     padding-right:0.5em;
#     font-weight: 600;
#     display: block;
# }
# .rq {
#     background-color: #fcf2f2;
#     border-color: #dFb5b4;
#     border-left: 5px solid #dfb5b4;
#     padding: 0.5em;
# }
# .rqE::before {
#     background-color: #fcd3d3;
#     color: #ff0000;
#     content:"Pay attention";
#     margin-left:-0.5em;
#     margin-right:-0.5em;
#     padding-left:0.5em;
#     padding-right:0.5em;
#     font-weight: 600;
#     display: block;
# }
# .rqE {
#     background-color: #fcd3d380;
#     border-color: #dFb5b4;
#     border-left: 5px solid #dfb5b4;
#     padding: 0.5em;
# }
# .rqT::before {
#     background-color: #fcd3d3;
#     color: #ff0000;
#     content: attr(title);
#     margin-left:-0.5em;
#     margin-right:-0.5em;
#     padding-left:0.5em;
#     padding-right:0.5em;
#     font-weight: 600;
#     display: block;
# }
# .rqT {
#     background-color: #fcd3d380;
#     border-color: #dFb5b4;
#     border-left: 5px solid #dfb5b4;
#     padding: 0.5em;
# }
# .exold {
#     background-color: #b2dbea80;
#     border-color: #0055ff;
#     border-left: 10px solid #0055ff;
#     padding: 0.5em;
# }
# .ex {
#     background-color: #b2dbea80;
#     padding: 0.5em;
#     padding-top: 0em;
#     position:relative;
# }
# .ex::before {
#     background-color: #b2dbea;
#     content:"Exercice. " attr(title);
#     margin-left:-0.5em;
#     margin-right:-0.5em;
#     padding-left:0.5em;
#     padding-right:0.5em;
#     font-weight: 600;
#     display: block;
# }
# .exE {
#     background-color: #b2dbea80;
#     padding: 0.5em;
#     padding-top: 0em;
#     position:relative;
#     color : #117996;
# }
# .exE::before {
#     background-color: #b2dbea;
#     content:"Exercise. " attr(title);
#     margin-left:-0.5em;
#     margin-right:-0.5em;
#     padding-left:0.5em;
#     padding-right:0.5em;
#     font-weight: 600;
#     display: block;
#     color : #117996;
# }
# .hint {
#     background-color: #dede6f80;
#     padding: 0.5em;
#     padding-top: 0em;
#     position:relative;
#     color : ##37665f;
# }
# .hint::before {
#     background-color: #dede6f;
#     content:"Indice(s). " attr(title);
#     margin-left:-0.5em;
#     margin-right:-0.5em;
#     padding-left:0.5em;
#     padding-right:0.5em;
#     font-weight: 600;
#     display: block;
#     color : ##37665f;
# }
# .hintE {
#     background-color: #dede6f80;
#     padding: 0.5em;
#     padding-top: 0em;
#     position:relative;
#     color : ##37665f;
# }
# .hintE::before {
#     background-color: #dede6f;
#     content:"Hint(s). " attr(title);
#     margin-left:-0.5em;
#     margin-right:-0.5em;
#     padding-left:0.5em;
#     padding-right:0.5em;
#     font-weight: 600;
#     display: block;
#     color : ##37665f;
# }
# .app {
#     background-color: #b2dbea80;
#     padding: 0.5em;
#     padding-top: 0em;
#     position:relative;
# }
# .app::before {
#     background-color: #b2dbea;
#     content:"Application";
#     margin-left:-0.5em;
#     margin-right:-0.5em;
#     padding-left:0.5em;
#     padding-right:0.5em;
#     font-weight: 600;
#     display: block;
# }
# .appE {
#     background-color: #b2dbea80;
#     padding: 0.5em;
#     padding-top: 0em;
#     color : #117996;
#     position:relative;
# }
# .appE::before {
#     background-color: #b2dbea;
#     content:"Application";
#     margin-left:-0.5em;
#     margin-right:-0.5em;
#     padding-left:0.5em;
#     padding-right:0.5em;
#     font-weight: 600;
#     color : #117996;
#     display: block;
# }
# .solFr {
#     background-color: #bbeab880;
#     padding: 0.5em;
#     padding-top: 0em;
#     position:relative;
# }
# .solFr::before {
#     background-color: #bbeab8;
#     content:"Solution";
#     margin-left:-0.5em;
#     margin-right:-0.5em;
#     padding-left:0.5em;
#     padding-right:0.5em;
#     font-weight: 600;
#     display: block;
# }.sol {
#     background-color: #bbeab880;
#     padding: 0.5em;
#     padding-top: 0em;
#     position:relative;
# }
# .sol::before {
#     background-color: #bbeab8;
#     content:"Answer";
#     margin-left:-0.5em;
#     margin-right:-0.5em;
#     padding-left:0.5em;
#     padding-right:0.5em;
#     font-weight: 600;
#     display: block;
# }
# .com {
#     background-color: #ffff7f80;
#     padding: 0.5em;
#     padding-top: 0em;
#     position:relative;
# }
# .com::before {
#     background-color: #ffff7f;
#     content:"Comment.";
#     margin-left:-0.5em;
#     margin-right:-0.5em;
#     padding-left:0.5em;
#     padding-right:0.5em;
#     font-weight: 600;
#     display: block;
# }
# div.todo:before {
#     content:url(data:image/png;base64,...);
#     float:left;
#     margin-left:20px;
#     margin-right:20px;
#     margin-top:20px;
#     margin-bottom:20px;
# }
# div.todo{
#     font-size: 1.1em;
#     margin-top:40px;
#     background-color: #b2dbea80;
# }
# div.todo ul{
#     margin: 0.2em;
# }
# div.todo li{
#     margin-left:60px;
#     margin-top:0;
#     margin-bottom:0;
# }
#
# figure {
#     border: 0px;
#     text-align: center;
#     margin: 5px; /* adjust as needed */
#     display: block;
#     margin: auto;
# }
# figure img {
#     vertical-align: top;
#     text-align: center;
#     display: block;
#     margin: auto;
# }
# figure figcaption {
#     border: 0px;
#     text-align: center;
#     font-size: 11px;
#     margin: auto;
# }
#
# </style>
# **Start at:** Sunday 12 October 2025, 11:32:42
# **Hostname:** device-8.home (Linux)
# <p style="text-align: center"><img width="800px" src="./config/svg/pyPhysChemBanner.svg" style="margin-left:auto; margin-right:auto"/></p>

# %% [markdown]
# # 🧭 Fall School 2025 — Participant Feedback Survey
#
# ## User Guide
#
# <div class="intro">
#
# Thank you for taking part in the **Introduction and Application of Data Science and Machine Learning to Molecular and Nanoscience Fall School 2025**!
# Université de Toulouse – Fall School 2025
# Contact: **Romuald Poteau** · romuald.poteau@utoulouse.fr
# Version: 2025-10-07
# Your feedback will help us improve the structure, materials, and mentoring sessions for future editions.
#
# ### 📦 1. Overview
#
# The evaluation survey is provided as a **Jupyter Notebook form** powered by the `SurveyApp` class.
# You can open it directly in your working environment — no external tool required.
#
# Each participant fills the survey **anonymously**, but a **unique ID (UID)** is automatically generated and saved locally to ensure data consistency.
#
#
# ### 🧰 2. Folder Structure
#
# When you launch the notebook, it automatically creates the following folder:
#
# ```bash
# ./ML_FallSchool2025-Evaluation/
# │
# ├── responses/ ← your personal draft and final survey files (.json / .csv)
# ├── summary/ ← summary files generated in admin mode (optional)
# └── survey_questions.yaml ← contains all questions and block titles. Don\'t change it
# ```
# <br>
# Your responses are saved in: `./ML_FallSchool2025-Evaluation/responses/`
#
# ### 🧑‍💻 3. Launching the Survey
#
# In your notebook, simply run the cell below this "how-to":
#
# ```python
# from tools4pyPhysChem import SurveyApp
#
# # Launch the participant mode
# survey = SurveyApp(mode="participant", base_dir="ML_FallSchool2025-Evaluation")
# survey.run()
# ```
# <br>
#
# This will display an interactive form divided into seven blocks:
#
# | Block | Title                                       | Description                                                            |
# | :---- | :------------------------------------------ | :--------------------------------------------------------------------- |
# | **A** | Technical Skills and Digital Literacy       | Confidence and baseline knowledge in Python and chemistry libraries    |
# | **B** | Conceptual Understanding of AI              | Understanding of ML and AI concepts                                    |
# | **C** | Learning Experience and Pedagogical Balance | Perception of pace, clarity, and balance between lectures and practice |
# | **D** | Mentored Project Experience                 | Teamwork, mentoring, and synthesis of acquired knowledge               |
# | **E** | Impact and Ethical Awareness                | Attitudes toward AI, perceived added value, and ethics                 |
# | **F** | Practical Transfer and Long-Term Usability  | Ability to reuse tools and integrate them in your own work             |
# | **G** | Free Comments  | Additional feedback, suggestions, or remarks about this week|
#
#
# ### ✍️ 4. Filling the Form
#
# Each block contains both quantitative (1–5 scale) and qualitative (text) questions.
#
# - Use the sliders for numeric answers (1 = low, 5 = high)
# - Write free text answers in the provided boxes
# - You can save drafts at any time with the button 💾 Save draft (they are at the json format!)
# - To reload a previous version, select it in the right field, and then use the 📂 Load draft dropdown
# Your answers are checked before submission:
# - Missing numeric answers or empty text fields are highlighted in red
# - **You will not be able to submit until all questions are complete**
#
# ### ✅ 5. Submitting Your Final Response
#
# Once you are satisfied with your answers, click:
# > ✅ Submit
#
# A confirmation message will appear, **unless some questions are incomplete**:
#
# > ✅ Response saved to `ML_FallSchool2025-Evaluation/responses/Response_<Your_UID>.csv`
# > This .csv file contains your complete, **anonymized answers**.
#
# ### ☁️ 6. Uploading Your File
#
# Please upload your generated `Response_<Your_UID>.csv` file to the shared folder below:
#
# > 📤 Upload link: [Google Drive – Fall School 2025 Feedback](https://drive.google.com/drive/folders/1Azepwta8BrTw84-Mj_0RjE4WVrbHQm3G?usp=sharing)
#
# **<div style="color:red">Please, do not upload a .json draft file!!!</div>**
#
# ### 🧭 Notes on Data Privacy
#
# Your answers are stored locally on your computer.
#
# A unique anonymous UID is created in a hidden file, so that the same user keeps the same identifier in future sessions:
#
# ```bash
# ./ML_FallSchool2025-Evaluation/.survey_id
# ```
#
# <br>
#
# > The syntax of `<Your_UID>` is `UID_<compact_date>_<token>`
# > where `<token>` is a random 6-character hexadecimal string
#
# This ensures your identity remains private while preserving data integrity.
#
# **Only the .csv file needs to be uploaded — do not send your drafts or the hidden ID file.**
#
# ### 🙏 Thank You
#
# Your time and feedback are invaluable.
# **The collective insights will help improve both the scientific and pedagogical aspects of the next Fall School**.
# </div>

# %% [markdown]
# ## Evaluation Survey for Participants
#
# <div class="intro">
#
# Run the next cell and answer the questions, see the User Guide if needed.
# </div>

# %%
# from tools4pyPhysChem import SurveyApp

# survey=SurveyApp(mode="participant",base_dir="ML_FallSchool2025-Evaluation")
# survey.run()

# %% [markdown]
# ## Teachers section
#
# <div class="intro">
#
# - Download the anonymized answers
# - Save them in the  `responses` subdolder
# - Uncomment the next lines and run them
# </div>

# %%
import tools4pyPhysChem as t4pPC
import importlib
importlib.reload(t4pPC)
from tools4pyPhysChem import SurveyApp

app = SurveyApp(mode="admin",base_dir="ML_FallSchool2025-Evaluation")
app.run()
# Out:
# ✅ Loaded 5 responses (34 columns)
# HTML(value='<h4>📊 All collected responses</h3>')
#    A1  A2  A3                                                 A4  B1  B2  \
# 0   1   1   2  L'installation et de se rappeller des lignes d...   5   4
# 1   4   1   3                     Dealing with images as arrays.   4   3
# 2   2   2   4  If you don't understand the code, when it chan...   3   4
# 3   1   1   1  the main vocabulary (columns, printing, operat...   2   5
# 4   2   1   3  Having the correct syntax when using multiple ...   4   3
#
#                                                   B3  \
# 0  Une très bonnes base pour éventuellement implé...
# 1  I learnt a bit about dealing with images in CN...
# 2  I learned how to do supervised AI by using pyt...
# 3  interesting, I can see it can help to gain tim...
# 4  databases curation, model building, explainabi...
#
#                                                   B4  \
# 0  Un outil statistique informatique qui permet d...
# 1  - It's a tool for generating models to predict...
# 2  It's a machine-trained neural network, that yo...
# 3  predict or explain things through linear regre...
# 4  A tool that can be used to large datasets to d...
#
#                                                   C1  \
# 0  Comment implementer et évaluer un réseau de ne...
# 1  Making models to analyse images - it was diffi...
# 2  I think all of it, I don't have a preference. ...
# 3  the preparation of the dataset and the creatio...
# 4                                      Using 2D CNNs
#
#                                                   C2  ...  F1 F2  F3  F4  F5  \
# 0                                           Les RNNs  ...   4  3   5   4   4
# 1                                     Explainable AI  ...   3  4   3   2   5
# 2  In my case, i'm interested in the un-supervize...  ...   5  3   4   4   5
# 3                    transmission microscopy images   ...   3  2   5   4   3
# 4  the differents types of model available in ten...  ...   3  5   4   5   5
#
#    F6  F7                                                 F8  \
# 0   1   4  Some RNNs for classification of time-dependent...
# 1   1   4  I will revisit many of the tools used, as I am...
# 2   3   5        I plan to reuse it for my data treatment :)
# 3   3   3  mainly in my lab, when we try new syntheses, t...
# 4   1   5  I definetly wish to try to apply it to SAXS da...
#
#                                                   G1                   id
# 0                                                NaN  UID_20251007_75AE87
# 1  I think it might be beneficial to cover slight...  UID_20251007_75AE87
# 2  It was amasing, and it went so fast ! Thank yo...  UID_20251007_75AE87
# 3  Thanks for all your help, availability and kin...  UID_20251007_75AE87
# 4  Specific instructions for macos installation w...  UID_20251010_84F477
#
# [5 rows x 34 columns]
# HTML(value='<h4>📈 Summary statistics</h4>')
#              A1        A2        A3        B1       B2        C3       C5  \
# count  5.000000  5.000000  5.000000  5.000000  5.00000  5.000000  5.00000
# mean   2.000000  1.200000  2.600000  3.600000  3.80000  2.600000  3.80000
# std    1.224745  0.447214  1.140175  1.140175  0.83666  1.140175  0.83666
# min    1.000000  1.000000  1.000000  2.000000  3.00000  1.000000  3.00000
# 25%    1.000000  1.000000  2.000000  3.000000  3.00000  2.000000  3.00000
# 50%    2.000000  1.000000  3.000000  4.000000  4.00000  3.000000  4.00000
# 75%    2.000000  1.000000  3.000000  4.000000  4.00000  3.000000  4.00000
# max    4.000000  2.000000  4.000000  5.000000  5.00000  4.000000  5.00000
#
#             C6        C7        D1  ...        E2       E3       E4        F1  \
# count  5.00000  5.000000  5.000000  ...  5.000000  5.00000  5.00000  5.000000
# mean   4.20000  3.600000  4.000000  ...  4.600000  3.20000  4.20000  3.600000
# std    0.83666  1.341641  1.224745  ...  0.547723  1.30384  0.83666  0.894427
# min    3.00000  2.000000  2.000000  ...  4.000000  1.00000  3.00000  3.000000
# 25%    4.00000  3.000000  4.000000  ...  4.000000  3.00000  4.00000  3.000000
# 50%    4.00000  3.000000  4.000000  ...  5.000000  4.00000  4.00000  3.000000
# 75%    5.00000  5.000000  5.000000  ...  5.000000  4.00000  5.00000  4.000000
# max    5.00000  5.000000  5.000000  ...  5.000000  4.00000  5.00000  5.000000
#
#              F2       F3        F4        F5        F6       F7
# count  5.000000  5.00000  5.000000  5.000000  5.000000  5.00000
# mean   3.400000  4.20000  3.800000  4.400000  1.800000  4.20000
# std    1.140175  0.83666  1.095445  0.894427  1.095445  0.83666
# min    2.000000  3.00000  2.000000  3.000000  1.000000  3.00000
# 25%    3.000000  4.00000  4.000000  4.000000  1.000000  4.00000
# 50%    3.000000  4.00000  4.000000  5.000000  1.000000  4.00000
# 75%    4.000000  5.00000  4.000000  5.000000  3.000000  5.00000
# max    5.000000  5.00000  5.000000  5.000000  3.000000  5.00000
#
# [8 rows x 23 columns]
# HTML(value="<h4>🕳 Missing values per column:</h4><div style='font-family:monospace;font-size:14px;'>A1=0 | A2=…
# HTML(value='<h4>🧠 Textual Analysis</h4>')
# 🧩 Textual questions detected: ['A4', 'B3', 'B4', 'C1', 'C2', 'C4', 'D5', 'E5', 'F8', 'G1']
#
# 📝 Top 15 words for 'A4':
# line           2
# application    1
# arrays         1
# basic          1
# change         1
# check          1
# code           1
# coding         1
# columns        1
# commands       1
# commmandes     1
# correct        1
# data           1
# dealing        1
# depending      1
# dtype: int64
# 💾 Saved ML_FallSchool2025-Evaluation/summary/WordCloud_A4.png
# 📝 Top 15 words for 'B3':
# afterward       1
# ai              1
# applications    1
# autonomie       1
# available       1
# base            1
# basic           1
# bit             1
# bonnes          1
# building        1
# ces             1
# chemical        1
# chemistry       1
# class           1
# cnns            1
# dtype: int64
# 💾 Saved ML_FallSchool2025-Evaluation/summary/WordCloud_B3.png
# 📝 Top 15 words for 'B4':
# data            3
# predict         2
# tool            2
# chronophages    1
# classify        1
# complexify      1
# datasets        1
# detect          1
# efficiently     1
# automatiser     1
# apply           1
# explain         1
# et              1
# future          1
# generating      1
# dtype: int64
# 💾 Saved ML_FallSchool2025-Evaluation/summary/WordCloud_B4.png
# 📝 Top 15 words for 'C1':
# think             2
# workflow          2
# 2d                1
# classification    1
# analyse           1
# cnns              1
# comment           1
# different         1
# difficult         1
# creation          1
# dataset           1
# evaluation        1
# got               1
# images            1
# implementer       1
# dtype: int64
# 💾 Saved ML_FallSchool2025-Evaluation/summary/WordCloud_C1.png
# 📝 Top 15 words for 'C2':
# ai             1
# analysis       1
# available      1
# case           1
# content        1
# course         1
# did            1
# differents     1
# environment    1
# explainable    1
# explore        1
# future         1
# images         1
# interested     1
# jupyter        1
# dtype: int64
# 💾 Saved ML_FallSchool2025-Evaluation/summary/WordCloud_C2.png
# 📝 Top 15 words for 'C4':
# code          3
# understand    3
# details       2
# python        2
# maybe         2
# chatgpt       2
# apply         1
# basic         1
# ask           1
# deeply        1
# depending     1
# doing         1
# examples      1
# just          1
# fast          1
# dtype: int64
# 💾 Saved ML_FallSchool2025-Evaluation/summary/WordCloud_C4.png
# 📝 Top 15 words for 'D5':
# image         2
# processing    2
# circle        1
# class         1
# evaluation    1
# cnn           1
# explain       1
# files         1
# focus         1
# attending     1
# images        1
# iris          1
# just          1
# model         1
# recognise     1
# dtype: int64
# 💾 Saved ML_FallSchool2025-Evaluation/summary/WordCloud_D5.png
# 📝 Top 15 words for 'E5':
# data           4
# shape          2
# concerning     2
# use            2
# absolutly      1
# avoiding       1
# aware          1
# aspect         1
# acquérir       1
# bias           1
# black          1
# challenging    1
# boxes          1
# change         1
# checking       1
# dtype: int64
# 💾 Saved ML_FallSchool2025-Evaluation/summary/WordCloud_E5.png
# 📝 Top 15 words for 'F8':
# data              3
# try               3
# treatment         2
# available         1
# apply             1
# compare           1
# classification    1
# best              1
# current           1
# development       1
# explore           1
# definetly         1
# dependent         1
# images            1
# lab               1
# dtype: int64
# 💾 Saved ML_FallSchool2025-Evaluation/summary/WordCloud_F8.png
# 📝 Top 15 words for 'G1':
# amasing         1
# appreciated     1
# availability    1
# beneficial      1
# coding          1
# cover           1
# encountered     1
# explain         1
# fast            1
# fewer           1
# focus           1
# help            1
# hidden          1
# installation    1
# instructions    1
# dtype: int64
# 💾 Saved ML_FallSchool2025-Evaluation/summary/WordCloud_G1.png
# 💾 Saved radar plot to ML_FallSchool2025-Evaluation/summary/Radar_BlockScores.png
# HTML(value='<h4>🧭 Semantic Clustering Map</h4>')
# ⚠️ Skipped semantic clustering (reason: No module named 'sentence_transformers')
# HTML(value='<h4>✅ Dashboard summary saved in:</h4><code>/home/romuald/ENSEIGNEMENT/1-JupyterNotebooks/pyPhysCh…

# %%
t4pPC.end()
# Out:
# **End at:** Tuesday 07 October 2025, 20:49:06
# **Duration:** 00:07:08 415ms
# <p style="text-align: center"><img width="800px" src="./config/svg/logoEnd.svg" style="margin-left:auto; margin-right:auto"/></p>
