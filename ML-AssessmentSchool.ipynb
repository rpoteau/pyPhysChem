# %%
# This now triggers vID.init() automatically via __init__.py
import pyphyschemtools as t4pPC
from pyphyschemtools import fg, hl, bg, color
t4pPC.init()
# %matplotlib inline

#cancel the "last show-up" behaviour of Jupyter notebooks
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"


__author__ = "Romuald Poteau, LPCNO (INSA-CNRS-UT lab, Toulouse, France)"
# Out:
# <style>
# h1, h2, h3, h4, h5, h6 {
#   font-family: Verdana, "DejaVu Sans", "Bitstream Vera Sans", Geneva, sans-serif;
#   font-weight: bold;
# }
# body, intro, introE, introT, rq, rqE, rqT, ex, exE, app, appE, sol, todo, hint, hintE, figure  {
#   font-family: Verdana, "DejaVu Sans", "Bitstream Vera Sans", Geneva, sans-serif;
#   font-weight: 400;
#   font-size: 12px;
# }
# h1 {
#   border: 0 solid #333;
#   padding: 30px ;
#   color: white;
#   background: #b11d01;
#   text-align: center;
# }
# h2 {
#   border: 3px solid #333;
#   padding: 18px ;
#   color: #b11d01;
#   background: #ffffff;
#   text-align: center;
# }
# h3 {
#   border: 0 solid #333;
#   padding: 12px ;
#   color: #000000;
#   background: #c1c1c1;
#   text-align: left;
# }
# h4 {
#   border: 0 solid #333;
#   padding: 2px ;
#   color: #000000;
#   background: #d9fffc;
#   text-align: left;
# }
# h5 {
#   border: 1px solid #333;
#   padding: 2px ;
#   color: #000000;
#   background: #ffffff;
#   text-align: left;
# }
# .introT::before {
#     content: attr(title);
#     background-color: #cecece;
#     margin-left:-0.5em;
#     margin-right:-0.5em;
#     padding-left:0.5em;
#     padding-right:0.5em;
#     font-weight: 600;
#     display: block;
# }
# .introT {
#     background-color: #cecece80;
#     border-color: #969696;
#     border-left: 5px solid #969696;
#     padding: 0.5em;
# }
# .intro {
#     background-color: #cecece80;
#     border-color: #969696;
#     border-left: 5px solid #969696;
#     padding: 0.5em;
# }
# .introE {
#     background-color: #cecece80;
#     border-color: #969696;
#     border-left: 5px solid #969696;
#     padding: 0.5em;
#     color : #117996;
# }
# .rq::before {
#     background-color: #fcd3d3;
#     color: #ff0000;
#     content:"Remarque";
#     margin-left:-0.5em;
#     margin-right:-0.5em;
#     padding-left:0.5em;
#     padding-right:0.5em;
#     font-weight: 600;
#     display: block;
# }
# .rq {
#     background-color: #fcf2f2;
#     border-color: #dFb5b4;
#     border-left: 5px solid #dfb5b4;
#     padding: 0.5em;
# }
# .rqE::before {
#     background-color: #fcd3d3;
#     color: #ff0000;
#     content:"Pay attention";
#     margin-left:-0.5em;
#     margin-right:-0.5em;
#     padding-left:0.5em;
#     padding-right:0.5em;
#     font-weight: 600;
#     display: block;
# }
# .rqE {
#     background-color: #fcd3d380;
#     border-color: #dFb5b4;
#     border-left: 5px solid #dfb5b4;
#     padding: 0.5em;
# }
# .rqT::before {
#     background-color: #fcd3d3;
#     color: #ff0000;
#     content: attr(title);
#     margin-left:-0.5em;
#     margin-right:-0.5em;
#     padding-left:0.5em;
#     padding-right:0.5em;
#     font-weight: 600;
#     display: block;
# }
# .rqT {
#     background-color: #fcd3d380;
#     border-color: #dFb5b4;
#     border-left: 5px solid #dfb5b4;
#     padding: 0.5em;
# }
# .exold {
#     background-color: #b2dbea80;
#     border-color: #0055ff;
#     border-left: 10px solid #0055ff;
#     padding: 0.5em;
# }
# .ex {
#     background-color: #b2dbea80;
#     padding: 0.5em;
#     padding-top: 0em;
#     position:relative;
# }
# .ex::before {
#     background-color: #b2dbea;
#     content:"Exercice. " attr(title);
#     margin-left:-0.5em;
#     margin-right:-0.5em;
#     padding-left:0.5em;
#     padding-right:0.5em;
#     font-weight: 600;
#     display: block;
# }
# .exE {
#     background-color: #b2dbea80;
#     padding: 0.5em;
#     padding-top: 0em;
#     position:relative;
#     color : #117996;
# }
# .exE::before {
#     background-color: #b2dbea;
#     content:"Exercise. " attr(title);
#     margin-left:-0.5em;
#     margin-right:-0.5em;
#     padding-left:0.5em;
#     padding-right:0.5em;
#     font-weight: 600;
#     display: block;
#     color : #117996;
# }
# .hint {
#     background-color: #dede6f80;
#     padding: 0.5em;
#     padding-top: 0em;
#     position:relative;
#     color : ##37665f;
# }
# .hint::before {
#     background-color: #dede6f;
#     content:"Indice(s). " attr(title);
#     margin-left:-0.5em;
#     margin-right:-0.5em;
#     padding-left:0.5em;
#     padding-right:0.5em;
#     font-weight: 600;
#     display: block;
#     color : ##37665f;
# }
# .hintE {
#     background-color: #dede6f80;
#     padding: 0.5em;
#     padding-top: 0em;
#     position:relative;
#     color : ##37665f;
# }
# .hintE::before {
#     background-color: #dede6f;
#     content:"Hint(s). " attr(title);
#     margin-left:-0.5em;
#     margin-right:-0.5em;
#     padding-left:0.5em;
#     padding-right:0.5em;
#     font-weight: 600;
#     display: block;
#     color : ##37665f;
# }
# .app {
#     background-color: #b2dbea80;
#     padding: 0.5em;
#     padding-top: 0em;
#     position:relative;
# }
# .app::before {
#     background-color: #b2dbea;
#     content:"Application";
#     margin-left:-0.5em;
#     margin-right:-0.5em;
#     padding-left:0.5em;
#     padding-right:0.5em;
#     font-weight: 600;
#     display: block;
# }
# .appE {
#     background-color: #b2dbea80;
#     padding: 0.5em;
#     padding-top: 0em;
#     color : #117996;
#     position:relative;
# }
# .appE::before {
#     background-color: #b2dbea;
#     content:"Application";
#     margin-left:-0.5em;
#     margin-right:-0.5em;
#     padding-left:0.5em;
#     padding-right:0.5em;
#     font-weight: 600;
#     color : #117996;
#     display: block;
# }
# .solFr {
#     background-color: #bbeab880;
#     padding: 0.5em;
#     padding-top: 0em;
#     position:relative;
# }
# .solFr::before {
#     background-color: #bbeab8;
#     content:"Solution";
#     margin-left:-0.5em;
#     margin-right:-0.5em;
#     padding-left:0.5em;
#     padding-right:0.5em;
#     font-weight: 600;
#     display: block;
# }.sol {
#     background-color: #bbeab880;
#     padding: 0.5em;
#     padding-top: 0em;
#     position:relative;
# }
# .sol::before {
#     background-color: #bbeab8;
#     content:"Answer";
#     margin-left:-0.5em;
#     margin-right:-0.5em;
#     padding-left:0.5em;
#     padding-right:0.5em;
#     font-weight: 600;
#     display: block;
# }
# .com {
#     background-color: #ffff7f80;
#     padding: 0.5em;
#     padding-top: 0em;
#     position:relative;
# }
# .com::before {
#     background-color: #ffff7f;
#     content:"Comment.";
#     margin-left:-0.5em;
#     margin-right:-0.5em;
#     padding-left:0.5em;
#     padding-right:0.5em;
#     font-weight: 600;
#     display: block;
# }
# div.todo:before {
#     content:url(data:image/png;base64,...);
#     float:left;
#     margin-left:20px;
#     margin-right:20px;
#     margin-top:20px;
#     margin-bottom:20px;
# }
# div.todo{
#     font-size: 1.1em;
#     margin-top:40px;
#     background-color: #b2dbea80;
# }
# div.todo ul{
#     margin: 0.2em;
# }
# div.todo li{
#     margin-left:60px;
#     margin-top:0;
#     margin-bottom:0;
# }
#
# figure {
#     border: 0px;
#     text-align: center;
#     margin: 5px; /* adjust as needed */
#     display: block;
#     margin: auto;
# }
# figure img {
#     vertical-align: top;
#     text-align: center;
#     display: block;
#     margin: auto;
# }
# figure figcaption {
#     border: 0px;
#     text-align: center;
#     font-size: 11px;
#     margin: auto;
# }
#
# </style>

# %% [markdown]
# # 🧭 Multiscale, Machine Learning and QSAR Methods Applied to Biomolecules, Aspet <br><br><u>Artificial Intelligence & Machine Learning in Chemistry, Thursday November 27 (Romuald POTEAU)</u><br><br>Participant Feedback Survey
#
# ## User Guide
#
# <div class="intro">
#
# Thank you for taking part in the **Artificial Intelligence & Machine Learning in Chemistry** evaluation!
# The session was part of the **Multiscale, Machine Learning and QSAR Methods Applied to Biomolecules** workshop, Aspet, 2025
# Contact: **Romuald Poteau** · romuald.poteau@utoulouse.fr
# Version: 2025-12-01
# Your feedback will help us improve the structure, materials, and mentoring sessions for future editions.
#
# ### 📦 1. Overview
#
# The evaluation survey is provided as a **Jupyter Notebook form** powered by the `SurveyApp` class.
# You can open it directly in your working environment — no external tool required.
#
# Each participant fills the survey **anonymously**, but a **unique ID (UID)** is automatically generated and saved locally to ensure data consistency.
#
#
# ### 🧰 2. Folder Structure
#
# When you launch the notebook, it automatically creates the following folder:
#
# ```bash
# ./Surveys/TCCM-MML_FallSchool2025/
# │
# ├── responses/ ← your personal draft and final survey files (.json / .csv)
# ├── summary/ ← summary files generated in admin mode (optional)
# └── survey_questions.yaml ← contains all questions and block titles. Don\'t change it
# ```
# <br>
# Your responses are saved in: `./Surveys/TCCM-MML_FallSchool2025/`
#
# ### 🧑‍💻 3. Launching the Survey
#
# In your notebook, simply run the cell below this "how-to":
#
# ```python
# from tools4pyPhysChem import SurveyApp
#
# # Launch the participant mode
# survey = SurveyApp(mode="participant", base_dir="Surveys/TCCM-MML_FallSchool2025")
# survey.run()
# ```
# <br>
#
# This will display an interactive form divided into seven blocks:
#
# | Block | Title                                       | Description                                                            |
# | :---- | :------------------------------------------ | :--------------------------------------------------------------------- |
# | **A** | Content of the Artificial Intelligence & Machine Learning in Chemistry lecture and tutorial  | Relevance, alignment with expectations, and possible redundancies        |
# | **B** | Technical Skills and Digital Literacy       | Confidence and baseline knowledge in Python and chemistry libraries    |
# | **C** | Conceptual Understanding of AI              | Understanding of ML and AI concepts                                    |
# | **D** | Learning Experience and Pedagogical Balance | Perception of pace, clarity, and balance between lectures and practice |
# | **E** | Impact and Ethical Awareness                | Attitudes toward AI, perceived added value, and ethics                 |
# | **F** | Practical Transfer and Long-Term Usability  | Ability to reuse tools and integrate them in your own work             |
# | **G** | Free Comments  | Additional feedback, suggestions, or remarks about this week|
#
#
# ### ✍️ 4. Filling the Form
#
# Each block contains both quantitative (1–5 scale) and qualitative (text) questions.
#
# - Use the sliders for numeric answers (1 = low, 5 = high)
# - Write free text answers in the provided boxes
# - All required text questions are indicated by a red asterisk (<span style="color:red">*</span>)
# - You can save drafts at any time with the button 💾 Save draft (they are at the json format!)
# - To reload a previous version, select it in the right field, and then use the 📂 Load draft dropdown
#
# Your answers are checked before submission:
# - Missing numeric answers or empty text fields are highlighted in red
# - **You will not be able to submit until all questions are complete**
#
# ### ✅ 5. Submitting Your Final Response
#
# Once you are satisfied with your answers, click:
# > ✅ Submit
#
# A confirmation message will appear, **unless some questions are incomplete**:
#
# > ✅ Response saved to `./Surveys/TCCM-MML_FallSchool2025/responses/Response_<Your_UID>.csv`
# > This .csv file contains your complete, **anonymized answers**.
#
# ### ☁️ 6. Uploading Your File
#
# Please upload your generated `Response_<Your_UID>.csv` file to the shared folder below:
#
# > 📤 Upload link: [Google Drive – TCCM-MML Fall School 2025 Feedback](https://drive.google.com/drive/folders/1BsbrSznUGrXwU9zKyQwWgGHrNHE9UFvW?usp=drive_link)
#
# **<span style="color:red">Please, do not upload a .json draft file!!!</span>**
#
# ### 🧭 Notes on Data Privacy
#
# Your answers are stored locally on your computer.
#
# A unique anonymous UID is created in a hidden file, so that the same user keeps the same identifier in future sessions:
#
# ```bash
# ./ML_FallSchool2025-Evaluation/.survey_id
# ```
#
# <br>
#
# > The syntax of `<Your_UID>` is `UID_<compact_date>_<token>`
# > where `<token>` is a random 6-character hexadecimal string
#
# This ensures your identity remains private while preserving data integrity.
#
# **Only the .csv file needs to be uploaded — do not send your drafts or the hidden ID file.**
#
# ### 🙏 Thank You
#
# Your time and feedback are invaluable.
# **The collective insights will help improve both the scientific and pedagogical aspects of the next Fall School**.
# </div>

# %% [markdown]
# ## Evaluation Survey for Participants
#
# <div class="intro">
#
# Run the next cell and answer the questions, see the User Guide if needed.
# </div>

# %%
from tools4pyPhysChem import SurveyApp

#survey=SurveyApp(mode="participant",base_dir="./Surveys/TCCM-MML_FallSchool2025")
survey=SurveyApp(mode="participant",base_dir="./Surveys/ML_FallSchoolNino2025-Evaluation/")
survey.run()
# Out:
#         <style>
#         /* Hover: track + rail */
#         .jp-InputSlider:hover .MuiSlider-track,
#         .jp-InputSlider:hover .MuiSlider-rail {
#             background-color: #1E90FF55 !important;
#         }
#
#         /* Hover: thumb */
#         .jp-InputSlider:hover .MuiSlider-thumb {
#             background-color: #1E90FF !important;
#             box-shadow: 0px 0px 4px #1E90FF !important;
#         }
#
#         /* Active: thumb when clicked or dragged */
#         .jp-InputSlider .MuiSlider-thumb.Mui-active {
#             background-color: #FF4500 !important;
#             box-shadow: 0px 0px 6px #FF4500 !important;
#         }
#         </style>
# VBox(children=(HTML(value="<b>🆔 Your anonymous ID:</b> <code>UID_20251007_75AE87</code><br><span style='color:…

# %% [markdown]
# ## Teachers section
#
# <div class="intro">
#
# - Download the anonymized answers
# - Save them in the  `responses` subdolder
# - Uncomment the next lines and run them
# </div>

# %%
import tools4pyPhysChem as t4pPC
import importlib
importlib.reload(t4pPC)
from tools4pyPhysChem import SurveyApp

app = SurveyApp(mode="admin",base_dir="Surveys/ML_FallSchoolNino2025-Evaluation")
app.run()
# Out:
# #####################################################
# #         RÉPARTITION DES QUESTIONS PAR BLOC        #
# #####################################################
#
# --- A. Block A. Technical Skills and Digital Literacy ---
#   [A1  ] NUMÉ(Slider) : I feel confident with Python.
#   [A2  ] NUMÉ(Slider) : I knew before the Fall School some chemistry-related Python libraries (RDKit, ASE, pymatgen).
#   [A3  ] NUMÉ(Slider) : I have already used ChatGPT or another generative AI for coding.
#   [A4  ] TEXTE(Libre) : What did I find most challenging when working with Python?
#
# --- B. Block B. Conceptual Understanding of AI ---
#   [B1  ] NUMÉ(Slider) : I can explain the differences between supervised, unsupervised, and explainable AI.
#   [B2  ] NUMÉ(Slider) : I perceive the role of AI in chemical research positively.
#   [B3  ] TEXTE(Libre) : How would I describe what I learned about AI during this week? (you can use a list of keywords).
#   [B4  ] TEXTE(Libre) : In a few words, how would I explain AI to a fellow chemist? (you can use a bullet point list)
#
# --- C. Block C. Learning Experience and Pedagogical Balance ---
#   [C1  ] TEXTE(Libre) : What was my favorite activity during the training?
#   [C2  ] TEXTE(Libre) : Which topics would I like to explore further?
#   [C3  ] NUMÉ(Slider) : The learning pace of the training was appropriate.
#   [C4  ] TEXTE(Libre) : What aspect of the learning pace or materials could be improved?
#   [C5  ] NUMÉ(Slider) : The balance between lectures and hands-on activities was appropriate.
#   [C6  ] NUMÉ(Slider) : I felt confident following the notebooks during live sessions.
#   [C7  ] NUMÉ(Slider) : The explanations given during exercises were clear and adapted to my level.
#
# --- D. Block D. Mentored Project Experience ---
#   [D1  ] NUMÉ(Slider) : The mentored project helped me synthesize and apply the week’s concepts.
#   [D2  ] NUMÉ(Slider) : The environment encouraged open discussions and exchange of ideas with other participants.
#   [D3  ] NUMÉ(Slider) : I could contribute actively to the mentored project.
#   [D5  ] TEXTE(Libre) : Briefly describe what my mentored project focused on.
#
# --- E. Block E. Impact and Ethical Awareness ---
#   [E1  ] NUMÉ(Slider) : A generative AI helped me understand my coding errors better.
#   [E2  ] NUMÉ(Slider) : I would recommend this training to peers.
#   [E3  ] NUMÉ(Slider) : I perceive the integration of an AI assistant into practical courses positively.
#   [E4  ] NUMÉ(Slider) : I feel more aware of the ethical implications of AI in scientific research.
#   [E5  ] TEXTE(Libre) : In my view, what is the main ethical challenge of using AI in chemistry?
#
# --- F. Block F. Practical Transfer and Long-Term Usability ---
#   [F1  ] NUMÉ(Slider) : I intend to use generative AI tools more thoughtfully in my future research.
#   [F2  ] NUMÉ(Slider) : I feel capable of running and adapting the provided notebooks independently after the school.
#   [F3  ] NUMÉ(Slider) : The instructions for installing Python and required libraries were clear and easy to follow.
#   [F4  ] NUMÉ(Slider) : Installing the environment on my own computer increased my confidence in using these tools in the future.
#   [F5  ] NUMÉ(Slider) : Having the material locally on my computer will help me integrate similar approaches in my own research or teaching.
#   [F6  ] NUMÉ(Slider) : In retrospect, I would have preferred to access the notebooks through a remote server rather than installing them locally.
#   [F7  ] NUMÉ(Slider) : The notebooks and datasets were well documented and can be re-used independently.
#   [F8  ] TEXTE(Libre) : How do I plan to reuse what I learned in my lab or teaching?
#
# --- G. Block G. Free Comments ---
#   [G1  ] TEXTE(Libre) : Any other comments, suggestions, or messages for the organizers?
#
# -----------------------------------------------------
# TOTAL : 23 questions numériques, 10 questions à champ libre.
# -----------------------------------------------------
# ✅ Loaded 6 responses (34 columns)
# ✅ Saved all responses to Excel: Surveys/ML_FallSchoolNino2025-Evaluation/summary/All_Responses_20251211_2110.xlsx
# HTML(value='<h4>📊 All collected responses</h3>')
#    A1  A2  A3                                                 A4  B1  B2  \
# 0   3   1   4  Find the right function which has been already...   4   5
# 1   1   1   2  L'installation et de se rappeller des lignes d...   5   4
# 2   4   1   3                     Dealing with images as arrays.   4   3
# 3   2   2   4  If you don't understand the code, when it chan...   3   4
# 4   1   1   1  the main vocabulary (columns, printing, operat...   2   5
# 5   2   1   3  Having the correct syntax when using multiple ...   4   3
#
#                                                   B3  \
# 0                                            usefull
# 1  Une très bonnes base pour éventuellement implé...
# 2  I learnt a bit about dealing with images in CN...
# 3  I learned how to do supervised AI by using pyt...
# 4  interesting, I can see it can help to gain tim...
# 5  databases curation, model building, explainabi...
#
#                                                   B4  \
# 0            analysis of experimental data or images
# 1  Un outil statistique informatique qui permet d...
# 2  - It's a tool for generating models to predict...
# 3  It's a machine-trained neural network, that yo...
# 4  predict or explain things through linear regre...
# 5  A tool that can be used to large datasets to d...
#
#                                                   C1  \
# 0                     tuesday with the various tools
# 1  Comment implementer et évaluer un réseau de ne...
# 2  Making models to analyse images - it was diffi...
# 3  I think all of it, I don't have a preference. ...
# 4  the preparation of the dataset and the creatio...
# 5                                      Using 2D CNNs
#
#                                                   C2  ...  F1 F2  F3  F4  F5  \
# 0            comparison between the various IA tools  ...   4  5   3   5   3
# 1                                           Les RNNs  ...   4  3   5   4   4
# 2                                     Explainable AI  ...   3  4   3   2   5
# 3  In my case, i'm interested in the un-supervize...  ...   5  3   4   4   5
# 4                    transmission microscopy images   ...   3  2   5   4   3
# 5  the differents types of model available in ten...  ...   3  5   4   5   5
#
#    F6  F7                                                 F8  \
# 0   1   5                                         read again
# 1   1   4  Some RNNs for classification of time-dependent...
# 2   1   4  I will revisit many of the tools used, as I am...
# 3   3   5        I plan to reuse it for my data treatment :)
# 4   3   3  mainly in my lab, when we try new syntheses, t...
# 5   1   5  I definetly wish to try to apply it to SAXS da...
#
#                                                   G1                   id
# 0  I suggest to spend less time on the change of ...  UID_20251007_75AE87
# 1                                                NaN  UID_20251007_75AE87
# 2  I think it might be beneficial to cover slight...  UID_20251007_75AE87
# 3  It was amasing, and it went so fast ! Thank yo...  UID_20251007_75AE87
# 4  Thanks for all your help, availability and kin...  UID_20251007_75AE87
# 5  Specific instructions for macos installation w...  UID_20251010_84F477
#
# [6 rows x 34 columns]
# HTML(value='<h4>📈 Summary statistics</h4>')
#              A1        A2        A3        B1        B2        C3        C5  \
# count  6.000000  6.000000  6.000000  6.000000  6.000000  6.000000  6.000000
# mean   2.166667  1.166667  2.833333  3.666667  4.000000  2.833333  3.666667
# std    1.169045  0.408248  1.169045  1.032796  0.894427  1.169045  0.816497
# min    1.000000  1.000000  1.000000  2.000000  3.000000  1.000000  3.000000
# 25%    1.250000  1.000000  2.250000  3.250000  3.250000  2.250000  3.000000
# 50%    2.000000  1.000000  3.000000  4.000000  4.000000  3.000000  3.500000
# 75%    2.750000  1.000000  3.750000  4.000000  4.750000  3.750000  4.000000
# max    4.000000  2.000000  4.000000  5.000000  5.000000  4.000000  5.000000
#
#              C6        C7        D1  ...        E2        E3        E4  \
# count  6.000000  6.000000  6.000000  ...  6.000000  6.000000  6.000000
# mean   4.166667  3.500000  3.833333  ...  4.333333  3.500000  3.666667
# std    0.752773  1.224745  1.169045  ...  0.816497  1.378405  1.505545
# min    3.000000  2.000000  2.000000  ...  3.000000  1.000000  1.000000
# 25%    4.000000  3.000000  3.250000  ...  4.000000  3.250000  3.250000
# 50%    4.000000  3.000000  4.000000  ...  4.500000  4.000000  4.000000
# 75%    4.750000  4.500000  4.750000  ...  5.000000  4.000000  4.750000
# max    5.000000  5.000000  5.000000  ...  5.000000  5.000000  5.000000
#
#              F1        F2        F3        F4        F5        F6        F7
# count  6.000000  6.000000  6.000000  6.000000  6.000000  6.000000  6.000000
# mean   3.666667  3.666667  4.000000  4.000000  4.166667  1.666667  4.333333
# std    0.816497  1.211060  0.894427  1.095445  0.983192  1.032796  0.816497
# min    3.000000  2.000000  3.000000  2.000000  3.000000  1.000000  3.000000
# 25%    3.000000  3.000000  3.250000  4.000000  3.250000  1.000000  4.000000
# 50%    3.500000  3.500000  4.000000  4.000000  4.500000  1.000000  4.500000
# 75%    4.000000  4.750000  4.750000  4.750000  5.000000  2.500000  5.000000
# max    5.000000  5.000000  5.000000  5.000000  5.000000  3.000000  5.000000
#
# [8 rows x 23 columns]
# HTML(value="<h4>🕳 Missing values per column:</h4><div style='font-family:monospace;font-size:14px;'>A1=0 | A2=…
# HTML(value='<h4>🧠 Textual Analysis</h4>')
# 🧩 Textual questions detected: ['A4', 'B3', 'B4', 'C1', 'C2', 'C4', 'D5', 'E5', 'F8', 'G1']
#
# 📝 Top 15 words for 'A4':
# line           2
# ai             1
# application    1
# libraries      1
# lignes         1
# lose           1
# lost           1
# main           1
# meaning        1
# multiple       1
# operations     1
# overcome       1
# plus           1
# printing       1
# python         1
# dtype: int64
# 💾 Saved Surveys/ML_FallSchoolNino2025-Evaluation/summary/WordCloud_A4.png
# 📝 Top 15 words for 'B3':
# afterward       1
# pour            1
# learned         1
# learnt          1
# libraries       1
# ma              1
# matrices        1
# model           1
# operations      1
# optimization    1
# outils          1
# parameters      1
# patterns        1
# pictures        1
# plan            1
# dtype: int64
# 💾 Saved Surveys/ML_FallSchoolNino2025-Evaluation/summary/WordCloud_B3.png
# 📝 Top 15 words for 'B4':
# data           4
# tool           2
# predict        2
# analysis       1
# results        1
# operations     1
# outil          1
# patterns       1
# permet         1
# preforms       1
# qui            1
# regression     1
# samples        1
# répétitives    1
# network        1
# dtype: int64
# 💾 Saved Surveys/ML_FallSchoolNino2025-Evaluation/summary/WordCloud_B4.png
# 📝 Top 15 words for 'C1':
# workflow       2
# think          2
# 2d             1
# time           1
# neurones       1
# pour           1
# preference     1
# preparation    1
# réseau         1
# thematic       1
# tools          1
# analyse        1
# training       1
# tuesday        1
# use            1
# dtype: int64
# 💾 Saved Surveys/ML_FallSchoolNino2025-Evaluation/summary/WordCloud_C1.png
# 📝 Top 15 words for 'C2':
# ai              1
# jupyter         1
# use             1
# types           1
# transmission    1
# tools           1
# time            1
# tensorflow      1
# supervized      1
# rnns            1
# nt              1
# model           1
# microscopy      1
# ll              1
# les             1
# dtype: int64
# 💾 Saved Surveys/ML_FallSchoolNino2025-Evaluation/summary/WordCloud_C2.png
# 📝 Top 15 words for 'C4':
# understand    3
# code          3
# maybe         2
# chatgpt       2
# details       2
# python        2
# solve         1
# need          1
# pace          1
# problems      1
# remark        1
# skills        1
# teacher       1
# student       1
# models        1
# dtype: int64
# 💾 Saved Surveys/ML_FallSchoolNino2025-Evaluation/summary/WordCloud_C4.png
# 📝 Top 15 words for 'D5':
# processing    2
# image         2
# attending     1
# used          1
# use           1
# trying        1
# triangle      1
# training      1
# time          1
# square        1
# shapeley      1
# saxs          1
# results       1
# recognise     1
# model         1
# dtype: int64
# 💾 Saved Surveys/ML_FallSchoolNino2025-Evaluation/summary/WordCloud_D5.png
# 📝 Top 15 words for 'E5':
# data           4
# concerning     2
# use            2
# shape          2
# models         1
# perspective    1
# outputs        1
# ou             1
# nouveau        1
# model          1
# python         1
# mentionned     1
# making         1
# make           1
# lot            1
# dtype: int64
# 💾 Saved Surveys/ML_FallSchoolNino2025-Evaluation/summary/WordCloud_E5.png
# 📝 Top 15 words for 'F8':
# try           3
# data          3
# treatment     2
# apply         1
# switching     1
# reuse         1
# revisit       1
# rnns          1
# saxs          1
# series        1
# starting      1
# tem           1
# syntheses     1
# processing    1
# time          1
# dtype: int64
# 💾 Saved Surveys/ML_FallSchoolNino2025-Evaluation/summary/WordCloud_F8.png
# 📝 Top 15 words for 'G1':
# ai           2
# various      2
# files        2
# tutorials    2
# data         2
# added        1
# ones         1
# research     1
# processed    1
# problems     1
# order        1
# network      1
# neural       1
# specific     1
# mystery      1
# dtype: int64
# 💾 Saved Surveys/ML_FallSchoolNino2025-Evaluation/summary/WordCloud_G1.png
# 💾 Saved radar plot to Surveys/ML_FallSchoolNino2025-Evaluation/summary/Radar_BlockScores.png
# HTML(value='<h4>🧭 Semantic Clustering Map</h4>')
# ⚠️ Skipped semantic clustering (reason: No module named 'sentence_transformers')
# HTML(value='<h4>✅ Dashboard summary saved in:</h4><code>/home/romuald/ENSEIGNEMENT/1-JupyterNotebooks/pyPhysCh…

# %%
t4pPC.end()
